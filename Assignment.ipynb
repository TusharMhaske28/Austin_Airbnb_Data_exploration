# %% [markdown]
# <a href="https://colab.research.google.com/github/TusharMhaske28/Austin_Airbnb_Data_exploration/blob/master/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopandas

# %%
# !git clone https://github.com/TusharMhaske28/Austin_Airbnb_Data_exploration.git
# Out:
# Cloning into 'Austin_Airbnb_Data_exploration'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (6/6), done.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
new_list = pd.read_csv('/content/Austin_Airbnb_Data_exploration/Dataset/listings.csv')
neighbourhoods = gpd.read_file('/content/Austin_Airbnb_Data_exploration/Dataset/neighbourhoods.geojson')
data = pd.read_json('/content/Austin_Airbnb_Data_exploration/Dataset/neighbourhoods.geojson')

geocsv = pd.read_csv('/content/Austin_Airbnb_Data_exploration/Dataset/neighbourhoods.csv')

# %%
new_list.head(5)
# Out:
#      id  ... availability_365
# 0  2265  ...              131
# 1  5245  ...                0
# 2  5456  ...              354
# 3  5636  ...               67
# 4  5769  ...               79
#
# [5 rows x 16 columns]

# %%
new_list = new_list.drop(labels=['neighbourhood_group','minimum_nights','last_review'],axis=1)

# %%
new_list.head(2)
# Out:
#      id  ... availability_365
# 0  2265  ...              131
# 1  5245  ...                0
#
# [2 rows x 13 columns]

# %%
region = neighbourhoods['neighbourhood']
region = np.array(region)
region2 = region
region = region.astype(np.int)
region
# Out:
# array([78739, 78754, 78732, 78737, 78756, 78747, 78751, 78712, 78738,
#        78725, 78757, 78728, 78744, 78736, 78702, 78741, 78719, 78742,
#        78722, 78703, 78717, 78749, 78730, 78745, 78731, 78748, 78729,
#        78752, 78724, 78704, 78753, 78705, 78758, 78746, 78759, 78726,
#        78733, 78723, 78750, 78735, 78721, 78727, 78734, 78701])

# %%
neighbourhoods.plot(figsize=(10,10))

# %%
plt.figure(figsize=(12,12))
for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys)
region2 = np.array(neighbourhoods['neighbourhood'])
plt.legend(labels=region2)
p1 = new_list['longitude']
p2 = new_list['latitude']
plt.scatter(p1,p2,alpha=0.3,marker='o',color='red')
plt.show()

# %%
max_list = new_list['neighbourhood'].value_counts().head(10).plot(kind='bar',figsize=(5,5),title="Top10 Neighbourhood with Max number of Listing")
max_list.set_xlabel('Neighbourhood')
max_list.set_ylabel('Count of Listing')
# Out:
# Text(0, 0.5, 'Count of Listing')

# %%
neigh = neighbourhoods.neighbourhood
neigh = np.array(neigh)
Dict = {}
k=0
for i in neigh:
  Dict[i] = k
  k=k+1

#for Neighbourhood 78704
plt.figure(figsize=(10,10))
x = np.array(data['features'][Dict['78704']]['geometry']['coordinates'])
x = x[0][0]
xs, ys = zip(*x)
plt.plot(xs,ys,color='black',linewidth=2)


#Listing for Neighbourhood 78704
df = new_list[new_list.neighbourhood==78704]
df1 = df[df.room_type=='Entire home/apt']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='red')

df1 = df[df.room_type=='Private room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='green')

df1 = df[df.room_type=='Shared room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='yellow')

df1 = df[df.room_type=='Hotel room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='pink')

plt.legend(['78704','Entire home/apt','Private room','Shared room','Hotel room'])

plt.show()

# %%
neigh = neighbourhoods.neighbourhood
neigh = np.array(neigh)
Dict = {}
k=0
for i in neigh:
  Dict[i] = k
  k=k+1

#for Neighbourhood 78702
plt.figure(figsize=(10,10))
x = np.array(data['features'][Dict['78702']]['geometry']['coordinates'])
x = x[0][0]
xs, ys = zip(*x)
plt.plot(xs,ys,color='black',linewidth=2)


#Listing for Neighbourhood 78702
df = new_list[new_list.neighbourhood==78702]
df1 = df[df.room_type=='Entire home/apt']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='red')

df1 = df[df.room_type=='Private room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='green')

df1 = df[df.room_type=='Shared room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='yellow')

df1 = df[df.room_type=='Hotel room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='pink')

plt.legend(['78702','Entire home/apt','Private room','Shared room','Hotel room'])


plt.show()

# %%
neigh = neighbourhoods.neighbourhood
neigh = np.array(neigh)
Dict = {}
k=0
for i in neigh:
  Dict[i] = k
  k=k+1

#for Neighbourhood 78701
plt.figure(figsize=(10,10))
x = np.array(data['features'][Dict['78701']]['geometry']['coordinates'])
x = x[0][0]
xs, ys = zip(*x)
plt.plot(xs,ys,color='black',linewidth=2)


#Listing for Neighbourhood 78701
df = new_list[new_list.neighbourhood==78701]
df1 = df[df.room_type=='Entire home/apt']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='red')

df1 = df[df.room_type=='Private room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='green')

df1 = df[df.room_type=='Shared room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='yellow')

df1 = df[df.room_type=='Hotel room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='pink')

plt.legend(['78704','Entire home/apt','Private room','Shared room','Hotel room'])


plt.show()

# %%
neigh = neighbourhoods.neighbourhood
neigh = np.array(neigh)
Dict = {}
k=0
for i in neigh:
  Dict[i] = k
  k=k+1

#for Neighbourhood 78741
plt.figure(figsize=(10,10))
x = np.array(data['features'][Dict['78741']]['geometry']['coordinates'])
x = x[0][0]
xs, ys = zip(*x)
plt.plot(xs,ys,color='black',linewidth=2)


#Listing for Neighbourhood 78741
df = new_list[new_list.neighbourhood==78741]
df1 = df[df.room_type=='Entire home/apt']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='red')

df1 = df[df.room_type=='Private room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='green')

df1 = df[df.room_type=='Shared room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='yellow')

df1 = df[df.room_type=='Hotel room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='pink')

plt.legend(['78704','Entire home/apt','Private room','Shared room','Hotel room'])


plt.show()

# %%
neigh = neighbourhoods.neighbourhood
neigh = np.array(neigh)
Dict = {}
k=0
for i in neigh:
  Dict[i] = k
  k=k+1

#for Neighbourhood 78703
plt.figure(figsize=(10,10))
x = np.array(data['features'][Dict['78703']]['geometry']['coordinates'])
x = x[0][0]
xs, ys = zip(*x)
plt.plot(xs,ys,color='black',linewidth=2)


#Listing for Neighbourhood 78703
df = new_list[new_list.neighbourhood==78703]
df1 = df[df.room_type=='Entire home/apt']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='red')

df1 = df[df.room_type=='Private room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='green')

df1 = df[df.room_type=='Shared room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='yellow')

df1 = df[df.room_type=='Hotel room']
y1 = df1['latitude']
x1 = df1['longitude']
plt.scatter(x1,y1,marker='o',color='pink')

plt.legend(['78702','Entire home/apt','Private room','Shared room','Hotel room'])


plt.show()

# %%
#TOP 10 Neighbourhoods by max no of listing


n = len(neighbourhoods['neighbourhood'])
region_index = {}

for i in range(0,n):
  region_index[region[i]]=i


plt.figure(figsize=(10,10))

for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,color='black',linewidth=0.5)


high_listing = np.array([78704, 78702,78701,78741,78703,78745,78705,78751,78723,78758])

for i in range(0,len(high_listing)):
  x = np.array(data['features'][region_index[high_listing[i]]]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,linewidth=3,color='black')


p1 = new_list['longitude']
p2 = new_list['latitude']
plt.scatter(p1,p2,alpha=0.3,marker='*',color='red')

plt.show()

# %%
new_list.head(2)
# Out:
#      id  ... availability_365
# 0  2265  ...              131
# 1  5245  ...                0
#
# [2 rows x 13 columns]

# %%
#Top 10 host by their total no of Listing

top_host = new_list['host_name'].value_counts().head(10).plot(kind='bar',figsize=(8,8),title='Top 10 Hosts')
top_host.set_xlabel('Host_name')
top_host.set_ylabel('Count of Listing')
# Out:
# Text(0, 0.5, 'Count of Listing')

# %%
room_types = new_list.room_type.unique()
room_types
# Out:
# array(['Entire home/apt', 'Private room', 'Hotel room', 'Shared room'],
#       dtype=object)

# %%
rooms = new_list['room_type'].value_counts().plot(kind='bar',figsize=(5,5),title='Types of room count')
rooms.set_xlabel('Types of Room')
rooms.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(10,10))

#for i in range(0,len(room_types)):
df1 = new_list[new_list['room_type']=='Entire home/apt']
x1 = df1.longitude
y1 = df1.latitude
plt.scatter(x1,y1,alpha=1,color='green')
plt.legend(labels=['Entire home/apt'])


for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,color='black',linewidth=1.5)


plt.show()

# %%
plt.figure(figsize=(10,10))

#for i in range(0,len(room_types)):
df1 = new_list[new_list['room_type']=='Private room']
x1 = df1.longitude
y1 = df1.latitude
plt.scatter(x1,y1,alpha=1,color='red')
plt.legend(labels=['Private room'])


for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,color='black',linewidth=1.5)


plt.show()

# %%
plt.figure(figsize=(10,10))

#for i in range(0,len(room_types)):
df1 = new_list[new_list['room_type']=='Hotel room']
x1 = df1.longitude
y1 = df1.latitude
plt.scatter(x1,y1,alpha=1,color='yellow')

df1 = new_list[new_list['room_type']=='Shared room']
x1 = df1.longitude
y1 = df1.latitude
plt.scatter(x1,y1,alpha=1,color='blue')
plt.legend(labels=['Hotel room','Shared room'])

n = len(neighbourhoods['neighbourhood'])
region_index = {}
for i in range(0,n):
  region_index[region[i]]=i


for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,color='black',linewidth=1.5)


plt.show()

# %%
neighbourhoods.head()
# Out:
#   neighbourhood  ...                                           geometry
# 0         78739  ...  MULTIPOLYGON (((-97.89002 30.20941, -97.88929 ...
# 1         78754  ...  MULTIPOLYGON (((-97.63658 30.40266, -97.63754 ...
# 2         78732  ...  MULTIPOLYGON (((-97.87303 30.43806, -97.87335 ...
# 3         78737  ...  MULTIPOLYGON (((-98.01876 30.24167, -98.01617 ...
# 4         78756  ...  MULTIPOLYGON (((-97.72792 30.32906, -97.72760 ...
#
# [5 rows x 3 columns]

# %%
new_list.price.max()
# Out:
# 16264

# %%
temp = new_list[new_list.price<500].plot(kind ='scatter' ,x='longitude',y='latitude',label='price',c='price',cmap=plt.get_cmap('jet'),colorbar=True,alpha=0.4,figsize=(10,10))
temp.legend()
for i in range(0,len(data)):
  x = np.array(data['features'][i]['geometry']['coordinates'])
  x = x[0][0]
  xs, ys = zip(*x)
  plt.plot(xs,ys,color='black',linewidth=1.5)
